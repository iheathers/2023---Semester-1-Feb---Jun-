# %%
import pandas as pd

# %%
dataframe = pd.read_csv('training.csv')

# %%
dropped_df = dataframe[dataframe.columns.drop(list(dataframe.filter(regex='pred_minus_obs')))]
dropped_df.head()
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9
# 0     d  67  51  68  115  69  111  136  31  67
# 1     s  67  28  51   99  50   97   82  26  59
# 2     s  63  26  50   95  49   91   81  26  57
# 3     d  63  42  63   97  66  108  111  28  59
# 4     s  46  27  50   83  51   90   76  26  56

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   class                325 non-null    object
#  1   b1                   325 non-null    int64
#  2   b2                   325 non-null    int64
#  3   b3                   325 non-null    int64
#  4   b4                   325 non-null    int64
#  5   b5                   325 non-null    int64
#  6   b6                   325 non-null    int64
#  7   b7                   325 non-null    int64
#  8   b8                   325 non-null    int64
#  9   b9                   325 non-null    int64
#  10  pred_minus_obs_H_b1  325 non-null    float64
#  11  pred_minus_obs_H_b2  325 non-null    float64
#  12  pred_minus_obs_H_b3  325 non-null    float64
#  13  pred_minus_obs_H_b4  325 non-null    float64
#  14  pred_minus_obs_H_b5  325 non-null    float64
# ...

# %%
dataframe.describe()
# Out:
#                b1          b2          b3          b4          b5          b6  \
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean    58.021538   38.381538   61.467692   96.175385   58.098462   99.196923
# std     11.705076   14.589516   15.003385   11.120136   10.654920    9.438789
# min     31.000000   23.000000   47.000000   69.000000   43.000000   83.000000
# 25%     50.000000   28.000000   52.000000   89.000000   51.000000   93.000000
# 50%     57.000000   32.000000   55.000000   95.000000   54.000000   96.000000
# 75%     65.000000   43.000000   65.000000  103.000000   63.000000  103.000000
# max    107.000000   91.000000  124.000000  141.000000  100.000000  138.000000
#
#                b7          b8          b9  pred_minus_obs_H_b1  ...  \
# count  325.000000  325.000000  325.000000           325.000000  ...
# mean    85.864615   27.375385   58.880000            55.786769  ...
# ...

# %%
dataframe['class'].value_counts()
# Out:
# s    136
# d    105
# o     46
# h     38
# Name: class, dtype: int64

# %%
import matplotlib.pyplot as plt

dataframe.plot(kind='scatter', x = 'b1', y = "class")
# Out:
# <AxesSubplot:xlabel='b1', ylabel='class'>

# %%
dropped_df.hist(bins=50, figsize=(12, 8))
plt.show()

# %%
import numpy as np

dropped_df_num = dropped_df.select_dtypes(include=[np.number])

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
dropped_df_num_scaled = std_scaler.fit_transform(dropped_df_num)

# %%
dropped_df_num_scaled
# Out:
# array([[ 0.76823994,  0.86623295,  0.43606029, ...,  3.01708854,
#          0.48758236,  0.91533208],
#        [ 0.76823994, -0.71267251, -0.69876454, ..., -0.23256801,
#         -0.1850164 ,  0.01352708],
#        [ 0.42598088, -0.84996863, -0.76551894, ..., -0.29274684,
#         -0.1850164 , -0.21192418],
#        ...,
#        [-0.7719258 , -0.84996863, -0.89902774, ..., -1.43614451,
#         -0.72309541, -0.66282668],
#        [-0.25853722, -0.84996863, -0.63201013, ..., -1.25560804,
#         -0.58857565, -0.3246498 ],
#        [ 1.11049899, -0.71267251, -0.69876454, ...,  0.36922024,
#         -0.31953615, -0.09919855]])

# %%
scaled_df_pd = pd.DataFrame(dropped_df_num_scaled)
scaled_df_pd
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.768240  0.866233  0.436060  1.695451  1.024724  1.252415  3.017089
# 1    0.768240 -0.712673 -0.698765  0.254401 -0.761240 -0.233114 -0.232568
# 2    0.425981 -0.849969 -0.765519 -0.105862 -0.855238 -0.869769 -0.292747
# 3    0.425981  0.248400  0.102288  0.074270  0.742729  0.934087  1.512618
# 4   -1.028620 -0.781321 -0.765519 -1.186649 -0.667242 -0.975878 -0.593641
# ..        ...       ...       ...       ...       ...       ...       ...
# 320 -0.258537  1.209473  0.703078 -0.466124  1.964705  1.464633  0.008147
# 321  0.939369  0.728937  0.970096 -0.466124 -0.573244 -0.869769  0.369220
# 322 -0.771926 -0.849969 -0.899028  0.974926  0.084743  0.509651 -1.436145
# 323 -0.258537 -0.849969 -0.632010 -0.376059 -0.291249 -0.127005 -1.255608
# 324  1.110499 -0.712673 -0.698765 -0.015796 -1.137232 -1.188096  0.369220
#
#             7         8
# 0    0.487582  0.915332
# 1   -0.185016  0.013527
# ...

# %%
scaled_df_pd.hist(bins=50, figsize=(10, 10))
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       1 from sklearn.linear_model import LogisticRegression
#       3 log_reg = LogisticRegression()
# ----> 4 log_reg.fit()
#
# TypeError: fit() missing 2 required positional arguments: 'X' and 'y'

# %%
np.linspace(0, 3, 1000).reshape(-1, 1)
# Out:
# array([[0.        ],
#        [0.003003  ],
#        [0.00600601],
#        [0.00900901],
#        [0.01201201],
#        [0.01501502],
#        [0.01801802],
#        [0.02102102],
#        [0.02402402],
#        [0.02702703],
#        [0.03003003],
#        [0.03303303],
#        [0.03603604],
#        [0.03903904],
#        [0.04204204],
#        [0.04504505],
#        [0.04804805],
#        [0.05105105],
#        [0.05405405],
#        [0.05705706],
#        [0.06006006],
#        [0.06306306],
#        [0.06606607],
#        [0.06906907],
#        [0.07207207],
#        [0.07507508],
#        [0.07807808],
#        [0.08108108],
#        [0.08408408],
#        [0.08708709],
#        [0.09009009],
#        [0.09309309],
#        [0.0960961 ],
#        [0.0990991 ],
#        [0.1021021 ],
#        [0.10510511],
#        [0.10810811],
#        [0.11111111],
#        [0.11411411],
#        [0.11711712],
#        [0.12012012],
#        [0.12312312],
#        [0.12612613],
# ...
